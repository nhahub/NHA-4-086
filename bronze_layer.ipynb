-- %%
USE CATALOG finance_intelligence_hub;

CREATE TABLE IF NOT EXISTS bronze.stocks_info (
    symbol STRING,
    name STRING,
    price_intraday STRING,
    change STRING,
    change_percent STRING,
    volume STRING,
    avg_vol_3m STRING,
    market_cap STRING,
    pe_ratio_ttm STRING,
    week_52_range STRING,
    region STRING,
    sector STRING,
    industry STRING,
    index_info STRING,
    category STRING,
    dwh_loaded_at TIMESTAMP
);
DROP TABLE IF EXISTS bronze.stock_prices_raw;
CREATE TABLE IF NOT EXISTS bronze.stock_prices_raw (
    price FLOAT,
    date TIMESTAMP,
    adj_close FLOAT,
    close FLOAT,
    high FLOAT,
    low FLOAT,
    open FLOAT,
    volume long,
    ticker STRING,
    category STRING,
    dwh_loaded_at TIMESTAMP
);
